# %%
import numpy as np

def random_predict() -> int:
    """Угадываем рандомное число
           
    Returns:
        int: Число попыток
    """
    number = np.random.randint(1, 101)
    count = 0
    min = 1
    max = 101
    
    while True:
        count += 1
        predict_number = (min+max)//2 #предполагаемое число
        if number > predict_number:
            min = predict_number
        elif number < predict_number:
            max = predict_number
        else:
            print(f"Компьютер угадал число за {count} попыток. Это число {predict_number}")
            break #Выход из цикла, если угадали
    return(count)

def score_game(random_predict) -> int:
    """За какое количество попыток в среднем за 1000 подходов угадывает наш алгоритм

    Args:
        random_predict ([type]): функция угадывания

    Returns:
        int: среднее количество попыток
    """
    count_ls = []
    np.random.seed(1)  # фиксируем сид для воспроизводимости
    random_array = np.random.randint(1, 101, size=(1000))  # загадали список чисел

    for number in random_array:
        count_ls.append(random_predict())

    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за: {score} попытки")
    
score_game(random_predict)
# Out:
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 7 попыток. Это число 37
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 17
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 7 попыток. Это число 73
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 7 попыток. Это число 46
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 6 попыток. Это число 42
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 6 попыток. Это число 49
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 5 попыток. Это число 97
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 7 попыток. Это число 37
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 7 попыток. Это число 3
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 42
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 7 попыток. Это число 46
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 73
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 6 попыток. Это число 17
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 7 попыток. Это число 37
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 7 попыток. Это число 46
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 3
# Компьютер угадал число за 5 попыток. Это число 97
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 7 попыток. Это число 46
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 6 попыток. Это число 17
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 7 попыток. Это число 46
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 3
# Компьютер угадал число за 5 попыток. Это число 91
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 6 попыток. Это число 17
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 7 попыток. Это число 37
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 5 попыток. Это число 97
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 49
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 6 попыток. Это число 42
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 5 попыток. Это число 97
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 7 попыток. Это число 59
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 7 попыток. Это число 48
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 7 попыток. Это число 73
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 73
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 7 попыток. Это число 3
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 98
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 5 попыток. Это число 16
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 7 попыток. Это число 65
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 6 попыток. Это число 49
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 6 попыток. Это число 77
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 3 попыток. Это число 88
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 6 попыток. Это число 89
# Компьютер угадал число за 7 попыток. Это число 71
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 4 попыток. Это число 7
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 5 попыток. Это число 29
# Компьютер угадал число за 6 попыток. Это число 58
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 7 попыток. Это число 23
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 5 попыток. Это число 72
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 3 попыток. Это число 13
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 5 попыток. Это число 97
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 6 попыток. Это число 74
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 3
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 7 попыток. Это число 1
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 6 попыток. Это число 70
# Компьютер угадал число за 5 попыток. Это число 10
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 4 попыток. Это число 94
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 7 попыток. Это число 43
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 6 попыток. Это число 24
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 4 попыток. Это число 32
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 7 попыток. Это число 6
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 6 попыток. Это число 83
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 5 попыток. Это число 47
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 7 попыток. Это число 50
# Компьютер угадал число за 6 попыток. Это число 52
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 7 попыток. Это число 31
# Компьютер угадал число за 6 попыток. Это число 11
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 6 попыток. Это число 5
# Компьютер угадал число за 6 попыток. Это число 8
# Компьютер угадал число за 6 попыток. Это число 55
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 6 попыток. Это число 42
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 14
# Компьютер угадал число за 7 попыток. Это число 12
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 67
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 6 попыток. Это число 95
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 6 попыток. Это число 86
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 7 попыток. Это число 75
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 4 попыток. Это число 82
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 7 попыток. Это число 87
# Компьютер угадал число за 7 попыток. Это число 37
# Компьютер угадал число за 7 попыток. Это число 15
# Компьютер угадал число за 5 попыток. Это число 4
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 5 попыток. Это число 85
# Компьютер угадал число за 7 попыток. Это число 73
# Компьютер угадал число за 4 попыток. Это число 44
# Компьютер угадал число за 7 попыток. Это число 100
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 56
# Компьютер угадал число за 7 попыток. Это число 18
# Компьютер угадал число за 6 попыток. Это число 61
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 84
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 7 попыток. Это число 96
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 1 попыток. Это число 51
# Компьютер угадал число за 7 попыток. Это число 81
# Компьютер угадал число за 6 попыток. Это число 92
# Компьютер угадал число за 6 попыток. Это число 80
# Компьютер угадал число за 6 попыток. Это число 27
# Компьютер угадал число за 3 попыток. Это число 38
# Компьютер угадал число за 7 попыток. Это число 25
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 5 попыток. Это число 41
# Компьютер угадал число за 7 попыток. Это число 53
# Компьютер угадал число за 6 попыток. Это число 39
# Компьютер угадал число за 6 попыток. Это число 20
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 7 попыток. Это число 21
# Компьютер угадал число за 6 попыток. Это число 64
# Компьютер угадал число за 5 попыток. Это число 22
# Компьютер угадал число за 5 попыток. Это число 66
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 4 попыток. Это число 19
# Компьютер угадал число за 4 попыток. Это число 69
# Компьютер угадал число за 6 попыток. Это число 17
# Компьютер угадал число за 5 попыток. Это число 79
# Компьютер угадал число за 5 попыток. Это число 60
# Компьютер угадал число за 4 попыток. Это число 57
# Компьютер угадал число за 6 попыток. Это число 45
# Компьютер угадал число за 6 попыток. Это число 36
# Компьютер угадал число за 7 попыток. Это число 40
# Компьютер угадал число за 7 попыток. Это число 62
# Компьютер угадал число за 6 попыток. Это число 33
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 5 попыток. Это число 54
# Компьютер угадал число за 3 попыток. Это число 63
# Компьютер угадал число за 2 попыток. Это число 76
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 5 попыток. Это число 35
# Компьютер угадал число за 7 попыток. Это число 34
# Компьютер угадал число за 7 попыток. Это число 93
# Компьютер угадал число за 2 попыток. Это число 26
# Компьютер угадал число за 7 попыток. Это число 68
# Компьютер угадал число за 6 попыток. Это число 2
# Компьютер угадал число за 6 попыток. Это число 99
# Компьютер угадал число за 7 попыток. Это число 9
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 7 попыток. Это число 28
# Компьютер угадал число за 6 попыток. Это число 30
# Компьютер угадал число за 7 попыток. Это число 90
# Компьютер угадал число за 7 попыток. Это число 78
# Компьютер угадал число за 6 попыток. Это число 11
# Ваш алгоритм угадывает число в среднем за: 5 попытки
