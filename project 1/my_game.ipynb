# %% [markdown]
# Игра "Компьютер загадывает и угадывает число"

# %%
from my_game import random_predict
from my_game import score_game

# %% [markdown]
# Угадываем рандомное число

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 5 попытки
